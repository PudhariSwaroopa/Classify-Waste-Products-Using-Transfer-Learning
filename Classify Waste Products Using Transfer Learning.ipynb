# %%
# !pip install tensorflow==2.17.0
# !pip install numpy
# !pip install scikit-learn==1.5.1
# !pip install matplotlib==3.9.2
# Out:
# Collecting tensorflow==2.17.0
#   Downloading tensorflow-2.17.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Collecting tensorflow-intel==2.17.0 (from tensorflow==2.17.0)
#   Downloading tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (4.25.9)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.80.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.14.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.47.0)
# Requirement already satisfied: rich in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (14.3.3)
# Requirement already satisfied: namex in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.1.0)
# Requirement already satisfied: optree in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.1.2)
# Downloading tensorflow-2.17.0-cp312-cp312-win_amd64.whl (2.0 kB)
# Downloading tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl (385.2 MB)
#    ---------------------------------------- 0.0/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.5/385.2 MB 466.4 kB/s eta 0:13:45
#    ---------------------------------------- 0.8/385.2 MB 645.7 kB/s eta 0:09:56
#    ---------------------------------------- 1.0/385.2 MB 751.8 kB/s eta 0:08:31
#    ---------------------------------------- 1.6/385.2 MB 1.1 MB/s eta 0:05:43
#    ---------------------------------------- 1.8/385.2 MB 1.2 MB/s eta 0:05:20
#    ---------------------------------------- 2.1/385.2 MB 1.2 MB/s eta 0:05:20
#    ---------------------------------------- 2.4/385.2 MB 1.2 MB/s eta 0:05:31
#    ---------------------------------------- 2.9/385.2 MB 1.3 MB/s eta 0:04:59
#    ---------------------------------------- 4.2/385.2 MB 1.7 MB/s eta 0:03:40
#    ---------------------------------------- 4.7/385.2 MB 1.9 MB/s eta 0:03:26
#     --------------------------------------- 5.8/385.2 MB 2.0 MB/s eta 0:03:07
#     --------------------------------------- 6.6/385.2 MB 2.2 MB/s eta 0:02:55
#     --------------------------------------- 7.3/385.2 MB 2.3 MB/s eta 0:02:47
#     --------------------------------------- 7.6/385.2 MB 2.3 MB/s eta 0:02:47
#     --------------------------------------- 8.7/385.2 MB 2.4 MB/s eta 0:02:39
#    - -------------------------------------- 9.7/385.2 MB 2.5 MB/s eta 0:02:28
#    - -------------------------------------- 10.2/385.2 MB 2.6 MB/s eta 0:02:27
#    - -------------------------------------- 10.7/385.2 MB 2.6 MB/s eta 0:02:26
#    - -------------------------------------- 11.5/385.2 MB 2.6 MB/s eta 0:02:24
#    - -------------------------------------- 12.1/385.2 MB 2.6 MB/s eta 0:02:23
#    - -------------------------------------- 12.6/385.2 MB 2.6 MB/s eta 0:02:23
#    - -------------------------------------- 13.1/385.2 MB 2.6 MB/s eta 0:02:23
#    - -------------------------------------- 14.2/385.2 MB 2.7 MB/s eta 0:02:19
#    - -------------------------------------- 15.7/385.2 MB 2.9 MB/s eta 0:02:10
#    - -------------------------------------- 16.8/385.2 MB 2.9 MB/s eta 0:02:06
#    - -------------------------------------- 17.3/385.2 MB 2.9 MB/s eta 0:02:06
#    - -------------------------------------- 18.9/385.2 MB 3.1 MB/s eta 0:01:59
#    -- ------------------------------------- 19.7/385.2 MB 3.1 MB/s eta 0:01:57
#    -- ------------------------------------- 19.9/385.2 MB 3.1 MB/s eta 0:01:59
#    -- ------------------------------------- 20.2/385.2 MB 3.0 MB/s eta 0:02:01
#    -- ------------------------------------- 20.4/385.2 MB 3.0 MB/s eta 0:02:04
#    -- ------------------------------------- 21.2/385.2 MB 3.0 MB/s eta 0:02:02
#    -- ------------------------------------- 22.3/385.2 MB 3.0 MB/s eta 0:02:00
#    -- ------------------------------------- 23.3/385.2 MB 3.1 MB/s eta 0:01:58
#    -- ------------------------------------- 24.6/385.2 MB 3.2 MB/s eta 0:01:54
#    -- ------------------------------------- 26.2/385.2 MB 3.3 MB/s eta 0:01:49
#    -- ------------------------------------- 28.0/385.2 MB 3.4 MB/s eta 0:01:45
#    --- ------------------------------------ 29.4/385.2 MB 3.5 MB/s eta 0:01:42
#    --- ------------------------------------ 30.9/385.2 MB 3.6 MB/s eta 0:01:39
#    --- ------------------------------------ 32.5/385.2 MB 3.7 MB/s eta 0:01:36
#    --- ------------------------------------ 33.6/385.2 MB 3.7 MB/s eta 0:01:34
#    --- ------------------------------------ 34.3/385.2 MB 3.7 MB/s eta 0:01:34
#    --- ------------------------------------ 35.7/385.2 MB 3.8 MB/s eta 0:01:32
#    --- ------------------------------------
3 MB/s eta 0:00:08
#    ---------------------------------- ----- 336.9/385.2 MB 6.3 MB/s eta 0:00:08
#    ----------------------------------- ---- 338.2/385.2 MB 6.3 MB/s eta 0:00:08
#    ----------------------------------- ---- 339.7/385.2 MB 6.3 MB/s eta 0:00:08
#    ----------------------------------- ---- 341.0/385.2 MB 6.3 MB/s eta 0:00:08
#    ----------------------------------- ---- 342.1/385.2 MB 6.3 MB/s eta 0:00:07
#    ----------------------------------- ---- 343.4/385.2 MB 6.2 MB/s eta 0:00:07
#    ----------------------------------- ---- 344.7/385.2 MB 6.2 MB/s eta 0:00:07
#    ----------------------------------- ---- 345.8/385.2 MB 6.2 MB/s eta 0:00:07
#    ----------------------------------- ---- 346.6/385.2 MB 6.2 MB/s eta 0:00:07
#    ------------------------------------ --- 348.1/385.2 MB 6.2 MB/s eta 0:00:06
#    ------------------------------------ --- 349.7/385.2 MB 6.2 MB/s eta 0:00:06
#    ------------------------------------ --- 351.5/385.2 MB 6.2 MB/s eta 0:00:06
#    ------------------------------------ --- 353.6/385.2 MB 6.2 MB/s eta 0:00:06
#    ------------------------------------ --- 355.5/385.2 MB 6.2 MB/s eta 0:00:05
#    ------------------------------------- -- 356.8/385.2 MB 6.2 MB/s eta 0:00:05
#    ------------------------------------- -- 358.4/385.2 MB 6.2 MB/s eta 0:00:05
#    ------------------------------------- -- 360.2/385.2 MB 6.2 MB/s eta 0:00:05
#    ------------------------------------- -- 362.0/385.2 MB 6.2 MB/s eta 0:00:04
#    ------------------------------------- -- 364.1/385.2 MB 6.2 MB/s eta 0:00:04
#    -------------------------------------- - 366.0/385.2 MB 6.2 MB/s eta 0:00:04
#    -------------------------------------- - 367.5/385.2 MB 6.2 MB/s eta 0:00:03
#    -------------------------------------- - 368.1/385.2 MB 6.1 MB/s eta 0:00:03
#    -------------------------------------- - 368.6/385.2 MB 6.1 MB/s eta 0:00:03
#    -------------------------------------- - 369.4/385.2 MB 6.1 MB/s eta 0:00:03
#    -------------------------------------- - 370.1/385.2 MB 6.1 MB/s eta 0:00:03
#    -------------------------------------- - 371.2/385.2 MB 6.0 MB/s eta 0:00:03
#    -------------------------------------- - 372.2/385.2 MB 6.0 MB/s eta 0:00:03
#    -------------------------------------- - 373.3/385.2 MB 6.0 MB/s eta 0:00:02
#    -------------------------------------- - 374.3/385.2 MB 6.0 MB/s eta 0:00:02
#    ---------------------------------------  375.7/385.2 MB 6.0 MB/s eta 0:00:02
#    ---------------------------------------  377.5/385.2 MB 6.0 MB/s eta 0:00:02
#    ---------------------------------------  379.1/385.2 MB 5.9 MB/s eta 0:00:02
#    ---------------------------------------  380.1/385.2 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  380.9/385.2 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  382.2/385.2 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  383.8/385.2 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  385.1/385.2 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  385.1/385.2 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 385.2/385.2 MB 5.8 MB/s eta 0:00:00
# Installing collected packages: tensorflow-intel, tensorflow
#   Attempting uninstall: tensorflow-intel
#     Found existing installation: tensorflow-intel 2.17.1
#     Uninstalling tensorflow-intel-2.17.1:
#       Successfully uninstalled tensorflow-intel-2.17.1
# Successfully installed tensorflow-2.17.0 tensorflow-intel-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-cpu 2.17.1 requires tensorflow-intel==2.17.1; platform_system == "Windows", but you have tensorflow-intel 2.17.0 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting scikit-learn==1.5.1
#   Downloading scikit_learn-1.5.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn==1.5.1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn==1.5.1) (1.17.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn==1.5.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn==1.5.1) (3.6.0)
# Downloading scikit_learn-1.5.1-cp312-cp312-win_amd64.whl (10.9 MB)
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/10.9 MB 7.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/10.9 MB 7.2 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/10.9 MB 6.6 MB/s eta 0:00:02
#    ------------------ --------------------- 5.0/10.9 MB 6.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/10.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/10.9 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/10.9 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/10.9 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.9 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.9/10.9 MB 5.8 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.8.0
#     Uninstalling scikit-learn-1.8.0:
#       Successfully uninstalled scikit-learn-1.8.0
# Successfully installed scikit-learn-1.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.3.0 requires transformers<6.0.0,>=4.41.0, but you have transformers 4.38.2 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib==3.9.2 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pudhari swaroopa\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import os
# import random, shutil
import glob


from matplotlib import pyplot as plt
from matplotlib import pyplot
from matplotlib.image import imread

# from os import makedirs,listdir
# from shutil import copyfile
# from random import seed
# from random import random

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# from tensorflow.keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D, Input
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.applications import InceptionV3
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
# Task 1

print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.17.0

# %%
import requests
import zipfile
from tqdm import tqdm

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/kd6057VPpABQ2FqCbgu9YQ/o-vs-r-split-reduced-1200.zip"
file_name = "o-vs-r-split-reduced-1200.zip"

print("Downloading file")
with requests.get(url, stream=True) as response:
    response.raise_for_status()
    with open(file_name, 'wb') as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)


def extract_file_with_progress(file_name):
    print("Extracting file with progress")
    with zipfile.ZipFile(file_name, 'r') as zip_ref:
        members = zip_ref.infolist() 
        with tqdm(total=len(members), unit='file') as progress_bar:
            for member in members:
                zip_ref.extract(member)
                progress_bar.update(1)
    print("Finished extracting file")


extract_file_with_progress(file_name)

print("Finished extracting file")
os.remove(file_name)
# Out:
# Downloading file
# Extracting file with progress
# 100%|██████████████████████████████████████████████████████████████████████████| 1207/1207 [00:00<00:00, 1404.32file/s]
# Finished extracting file
# Finished extracting file

# %%
img_rows, img_cols = 150, 150
batch_size = 32
n_epochs = 10
n_classes = 2
val_split = 0.2
verbosity = 1
path = 'o-vs-r-split/train/'
path_test = 'o-vs-r-split/test/'
input_shape = (img_rows, img_cols, 3)
labels = ['O', 'R']
seed = 42

# %%
# Create ImageDataGenerators for training and validation and testing
train_datagen = ImageDataGenerator(
    validation_split = val_split,
    rescale=1.0/255.0,
	width_shift_range=0.1, 
    height_shift_range=0.1, 
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(
    validation_split = val_split,
    rescale=1.0/255.0,
)

test_datagen = ImageDataGenerator(
    rescale=1.0/255.0
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = path,
    seed = seed,
    batch_size = batch_size, 
    class_mode='binary',
    shuffle = True,
    target_size=(img_rows, img_cols),
    subset = 'training'
)
# Out:
# Found 800 images belonging to 2 classes.

# %%
val_generator = val_datagen.flow_from_directory(
    directory = path,
    seed = seed,
    batch_size = batch_size, 
    class_mode='binary',
    shuffle = True,
    target_size=(img_rows, img_cols),
    subset = 'validation'
)
# Out:
# Found 200 images belonging to 2 classes.

# %%
# Task 2

test_generator = test_datagen.flow_from_directory(
    directory=path_test,
    class_mode='binary',
    seed=seed,
    batch_size=batch_size,
    shuffle=False,
    target_size=(img_rows, img_cols)
)

test_generator
# Out:
# Found 200 images belonging to 2 classes.

# %%
# Task 3

print("Length of train_generator:", len(train_generator))
# Out:
# Length of train_generator: 25

# %%
from pathlib import Path

IMG_DIM = (100, 100)

train_files = glob.glob('./o-vs-r-split/train/O/*')
train_files = train_files[:20]
train_imgs = [tf.keras.preprocessing.image.img_to_array(tf.keras.preprocessing.image.load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [Path(fn).parent.name for fn in train_files]

img_id = 0
O_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
O = [next(O_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in O])
l = [ax[i].imshow(O[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['O', 'O', 'O', 'O', 'O']

# %%
from tensorflow.keras.applications import vgg16

input_shape = (150, 150, 3)
vgg = vgg16.VGG16(include_top=False,
                        weights='imagenet',
                        input_shape=input_shape)

# %%
output = vgg.layers[-1].output
output = tf.keras.layers.Flatten()(output)
basemodel = Model(vgg.input, output)

# %%
for layer in basemodel.layers: 
    layer.trainable = False

# %%
input_shape = basemodel.output_shape[1]

model = Sequential()
model.add(basemodel)
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# %%
# Task 4

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ functional (Functional)              │ (None, 8192)                │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       4,194,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 19,172,673 (73.14 MB)
#  Trainable params: 4,457,985 (17.01 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
# Task 5

for layer in basemodel.layers: 
    layer.trainable = False
model.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import LearningRateScheduler


checkpoint_path='O_R_tlearn_vgg16.keras'

# define step decay function
class LossHistory_(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.lr = []
        
    def on_epoch_end(self, epoch, logs={}):
        self.losses.append(logs.get('loss'))
        self.lr.append(exp_decay(epoch))
        print('lr:', exp_decay(len(self.losses)))

def exp_decay(epoch):
    initial_lrate = 1e-4
    k = 0.1
    lrate = initial_lrate * np.exp(-k*epoch)
    return lrate

# learning schedule callback
loss_history_ = LossHistory_()
lrate_ = LearningRateScheduler(exp_decay)

keras_callbacks = [
      EarlyStopping(monitor = 'val_loss', 
                    patience = 4, 
                    mode = 'min', 
                    min_delta=0.01),
      ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')
]

callbacks_list_ = [loss_history_, lrate_] + keras_callbacks

# %%
extract_feat_model = model.fit(train_generator, 
                               steps_per_epoch=5, 
                               epochs=10,
                               callbacks = callbacks_list_,   
                               validation_data=val_generator, 
                               validation_steps=val_generator.samples // batch_size, 
                               verbose=1)
# Out:
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4875 - loss: 0.7026lr: 9.048374180359596e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 8s/step - accuracy: 0.5000 - loss: 0.6847 - val_accuracy: 0.6771 - val_loss: 0.6101 - learning_rate: 1.0000e-04
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6538 - loss: 0.6083lr: 8.187307530779819e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 9s/step - accuracy: 0.6438 - loss: 0.6174 - val_accuracy: 0.7604 - val_loss: 0.5474 - learning_rate: 9.0484e-05
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6547 - loss: 0.6059lr: 7.408182206817179e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 8s/step - accuracy: 0.6562 - loss: 0.5982 - val_accuracy: 0.7656 - val_loss: 0.5103 - learning_rate: 8.1873e-05
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6854 - loss: 0.5821lr: 6.703200460356394e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 7s/step - accuracy: 0.7188 - loss: 0.5745 - val_accuracy: 0.7552 - val_loss: 0.5118 - learning_rate: 7.4082e-05
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7378 - loss: 0.5209lr: 6.065306597126335e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 8s/step - accuracy: 0.7437 - loss: 0.5212 - val_accuracy: 0.7812 - val_loss: 0.4614 - learning_rate: 6.7032e-05
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8154 - loss: 0.4810lr: 5.488116360940264e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 8s/step - accuracy: 0.8062 - loss: 0.4566 - val_accuracy: 0.8385 - val_loss: 0.4278 - learning_rate: 6.0653e-05
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8282 - loss: 0.4256lr: 4.965853037914095e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 8s/step - accuracy: 0.8313 - loss: 0.4390 - val_accuracy: 0.8385 - val_loss: 0.4121 - learning_rate: 5.4881e-05
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8010 - loss: 0.4379lr: 4.493289641172216e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 8s/step - accuracy: 0.8125 - loss: 0.4202 - val_accuracy: 0.8333 - val_loss: 0.3903 - learning_rate: 4.9659e-05
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8116 - loss: 0.4084lr: 4.0656965974059915e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 8s/step - accuracy: 0.8000 - loss: 0.4202 - val_accuracy: 0.8281 - val_loss: 0.3966 - learning_rate: 4.4933e-05
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8366 - loss: 0.3823lr: 3.678794411714424e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 8s/step - accuracy: 0.8313 - loss: 0.4061 - val_accuracy: 0.8333 - val_loss: 0.3670 - learning_rate: 4.0657e-05

# %%
import matplotlib.pyplot as plt

history = extract_feat_model

# plot loss curve
plt.figure(figsize=(5, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Task 6

history = extract_feat_model

plt.figure(figsize=(5,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from tensorflow.keras.applications import vgg16

input_shape = (150, 150, 3)
vgg = vgg16.VGG16(include_top=False,
                        weights='imagenet',
                        input_shape=input_shape)

output = vgg.layers[-1].output
output = tf.keras.layers.Flatten()(output)
basemodel = Model(vgg.input, output)

for layer in basemodel.layers: 
    layer.trainable = False

display([layer.name for layer in basemodel.layers])

set_trainable = False

for layer in basemodel.layers:
    if layer.name in ['block5_conv3']:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

for layer in basemodel.layers:
    print(f"{layer.name}: {layer.trainable}")
# Out:
# ['input_layer_2',
#  'block1_conv1',
#  'block1_conv2',
#  'block1_pool',
#  'block2_conv1',
#  'block2_conv2',
#  'block2_pool',
#  'block3_conv1',
#  'block3_conv2',
#  'block3_conv3',
#  'block3_pool',
#  'block4_conv1',
#  'block4_conv2',
#  'block4_conv3',
#  'block4_pool',
#  'block5_conv1',
#  'block5_conv2',
#  'block5_conv3',
#  'block5_pool',
#  'flatten_1']
# input_layer_2: False
# block1_conv1: False
# block1_conv2: False
# block1_pool: False
# block2_conv1: False
# block2_conv2: False
# block2_pool: False
# block3_conv1: False
# block3_conv2: False
# block3_conv3: False
# block3_pool: False
# block4_conv1: False
# block4_conv2: False
# block4_conv3: False
# block4_pool: False
# block5_conv1: False
# block5_conv2: False
# block5_conv3: True
# block5_pool: True
# flatten_1: True

# %%
model = Sequential()
model.add(basemodel)
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

checkpoint_path='O_R_tlearn_fine_tune_vgg16.keras'

# learning schedule callback
loss_history_ = LossHistory_()
lrate_ = LearningRateScheduler(exp_decay)

keras_callbacks = [
      EarlyStopping(monitor = 'val_loss', 
                    patience = 4, 
                    mode = 'min', 
                    min_delta=0.01),
      ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')
]

callbacks_list_ = [loss_history_, lrate_] + keras_callbacks

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(learning_rate=1e-4),
              metrics=['accuracy'])

fine_tune_model = model.fit(train_generator, 
                    steps_per_epoch=5, 
                    epochs=10,
                    callbacks = callbacks_list_,   
                    validation_data=val_generator, 
                    validation_steps=val_generator.samples // batch_size, 
                    verbose=1)
# Out:
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6236 - loss: 0.6944lr: 9.048374180359596e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 8s/step - accuracy: 0.6313 - loss: 0.7169 - val_accuracy: 0.7344 - val_loss: 0.5543 - learning_rate: 1.0000e-04
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7309 - loss: 0.5568lr: 8.187307530779819e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 8s/step - accuracy: 0.6938 - loss: 0.5737 - val_accuracy: 0.7500 - val_loss: 0.4947 - learning_rate: 9.0484e-05
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7973 - loss: 0.4898lr: 7.408182206817179e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 8s/step - accuracy: 0.7937 - loss: 0.4689 - val_accuracy: 0.8281 - val_loss: 0.4097 - learning_rate: 8.1873e-05
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8551 - loss: 0.4198lr: 6.703200460356394e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 8s/step - accuracy: 0.8250 - loss: 0.4329 - val_accuracy: 0.7865 - val_loss: 0.4352 - learning_rate: 7.4082e-05
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7403 - loss: 0.4520lr: 6.065306597126335e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 8s/step - accuracy: 0.7563 - loss: 0.4487 - val_accuracy: 0.8646 - val_loss: 0.3269 - learning_rate: 6.7032e-05
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8661 - loss: 0.3580lr: 5.488116360940264e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 8s/step - accuracy: 0.8438 - loss: 0.3918 - val_accuracy: 0.8906 - val_loss: 0.2974 - learning_rate: 6.0653e-05
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8462 - loss: 0.3764lr: 4.965853037914095e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 8s/step - accuracy: 0.8562 - loss: 0.3474 - val_accuracy: 0.8854 - val_loss: 0.2874 - learning_rate: 5.4881e-05
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8358 - loss: 0.4050lr: 4.493289641172216e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 8s/step - accuracy: 0.8562 - loss: 0.3938 - val_accuracy: 0.8854 - val_loss: 0.2843 - learning_rate: 4.9659e-05
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8395 - loss: 0.3124lr: 4.0656965974059915e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 8s/step - accuracy: 0.8562 - loss: 0.3238 - val_accuracy: 0.8698 - val_loss: 0.2873 - learning_rate: 4.4933e-05
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8935 - loss: 0.3373lr: 3.678794411714424e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 8s/step - accuracy: 0.9000 - loss: 0.2992 - val_accuracy: 0.8698 - val_loss: 0.2697 - learning_rate: 4.0657e-05

# %%
# Task 7

history = fine_tune_model

plt.figure(figsize=(5,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()# Task 7

history = fine_tune_model

plt.figure(figsize=(5,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Task 8

history = fine_tune_model

plt.figure(figsize=(5,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from pathlib import Path

# Load saved models
extract_feat_model = tf.keras.models.load_model('O_R_tlearn_vgg16.keras')
fine_tune_model = tf.keras.models.load_model('O_R_tlearn_fine_tune_vgg16.keras')

IMG_DIM = (150, 150)

# Load test images
test_files_O = glob.glob('./o-vs-r-split/test/O/*')
test_files_R = glob.glob('./o-vs-r-split/test/R/*')
test_files = test_files_O[:50] + test_files_R[:50]

test_imgs = [tf.keras.preprocessing.image.img_to_array(tf.keras.preprocessing.image.load_img(img, target_size=IMG_DIM)) for img in test_files]
test_imgs = np.array(test_imgs)
test_labels = [Path(fn).parent.name for fn in test_files]

# Standardize
test_imgs_scaled = test_imgs.astype('float32')
test_imgs_scaled /= 255

class2num_lt = lambda l: [0 if x == 'O' else 1 for x in l]
num2class_lt = lambda l: ['O' if x < 0.5 else 'R' for x in l]

test_labels_enc = class2num_lt(test_labels)

# Make predictions for both models
predictions_extract_feat_model = extract_feat_model.predict(test_imgs_scaled, verbose=0)
predictions_fine_tune_model = fine_tune_model.predict(test_imgs_scaled, verbose=0)

# Convert predictions to class labels
predictions_extract_feat_model = num2class_lt(predictions_extract_feat_model)
predictions_fine_tune_model = num2class_lt(predictions_fine_tune_model)

# Print classification report for both models
print('Extract Features Model')
print(metrics.classification_report(test_labels, predictions_extract_feat_model))
print('Fine-Tuned Model')
print(metrics.classification_report(test_labels, predictions_fine_tune_model))
# Out:
# Extract Features Model
#               precision    recall  f1-score   support
#
#            O       0.75      0.78      0.76        50
#            R       0.77      0.74      0.76        50
#
#     accuracy                           0.76       100
#    macro avg       0.76      0.76      0.76       100
# weighted avg       0.76      0.76      0.76       100
#
# Fine-Tuned Model
#               precision    recall  f1-score   support
#
#            O       0.78      0.90      0.83        50
#            R       0.88      0.74      0.80        50
#
#     accuracy                           0.82       100
#    macro avg       0.83      0.82      0.82       100
# weighted avg       0.83      0.82      0.82       100

# %%
# Plot one of the images with actual label and predicted label as title
def plot_image_with_title(image, model_name, actual_label, predicted_label):
    plt.imshow(image)
    plt.title(f"Model: {model_name}, Actual: {actual_label}, Predicted: {predicted_label}")
    plt.axis('off')
    plt.show()

# Specify index of image to plot, for example index 0
index_to_plot = 0
plot_image_with_title(
    image=test_imgs[index_to_plot].astype('uint8'),
    model_name='Extract Features Model',
    actual_label=test_labels[index_to_plot], 
    predicted_label=predictions_extract_feat_model[index_to_plot],
    )

# %%
def plot_image_with_title(image, model_name, actual_label, predicted_label):
    plt.figure(figsize=(5,5))
    plt.imshow(image.astype("uint8"))
    plt.title(
        f"{model_name}\nActual: {actual_label} | Predicted: {predicted_label}"
    )
    plt.axis('off')
    plt.show()

# %%
# Task 9

index_to_plot = 1

plot_image_with_title(
    image=test_imgs[index_to_plot],
    model_name='Extract Features Model',
    actual_label=test_labels[index_to_plot],
    predicted_label=predictions_extract_feat_model[index_to_plot]
)

# %%
# Task 10

index_to_plot = 1

plot_image_with_title(
    image=test_imgs[index_to_plot],
    model_name='Fine-Tuned Model',
    actual_label=test_labels[index_to_plot],
    predicted_label=predictions_fine_tune_model[index_to_plot]
)
